# %%
import numpy as np
import pandas as pd

# %%
t_m_tr = pd.read_csv("t_m_tr.csv")

# %%
db_a = t_m_tr.sort_values(by = " count_sum")

db_1 = db_a[db_a["count_sum"]==1]
db_n1 = db_a[db_a["count_sum"]==1].index.values
db_not1 = db_a.drop(db_n1,axis = 0)
# Out:
#         Unnamed: 0                                          msno  \
# 0                0  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=
# 1                1  +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=
# 2                2  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=
# 3                3  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=
# 4                4  ++/UDNo9DLrxT8QVGiDi1OnWfczAdEwThaVyD0fXO50=
# 5                5  ++/ZHqwUNa7U21Qz+zqteiXlZapxey86l6eEorrak/g=
# 6                6  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=
# 7                7  ++0nOC7BmrUTtcSboRORfg6ZXTajnBDt1f/SEgH6ONo=
# 8                8  ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=
# 9                9  ++1GCIyXZO7834NjDKmcK1lBVLQi9PsN6sOC7wfW+8g=
# 10              10  ++38dVm0EHKCOfND6oEal3xFKtqJYZTZJmnpbAOOZBk=
# 11              11  ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=
# 12              12  ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=
# ...
