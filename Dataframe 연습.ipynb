# %%
import pandas as pd

# %%
## dataframe 만들기

data_1 = {
    'year' : ["1992","1991","1994"],
    'gender' : ["male","female","female"],
    "city" : ["Ansan","seoul","Ansan"]
}
df_1 = pd.DataFrame(data_1) 
df_1
# Out:
#     city  gender  year
# 0  Ansan    male  1992
# 1  seoul  female  1991
# 2  Ansan  female  1994

# %%
df_1 = df_1.drop([0]) ### df_1.drop 만 쓰면 실제 데이터인 df_1에 영향을 주지 못한다.
df_1
# Out:
#     city  gender  year
# 1  seoul  female  1991
# 2  Ansan  female  1994

# %%
data.drop()

# %%
## 데이터 불러오기
df_0 = pd.read_csv("D:/Users/Kwon/Desktop/DATABASE/kkbox-churn-prediction-challenge/first/transactions_v2.csv/data/churn_comp_refresh/transactions_v2.csv")

# %%
df_0[:98]
# Out:
#                                             msno  payment_method_id  \
# 0   ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1   ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2   +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3   +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4   +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
# 5   +0KcMm8JNCW08lTp3Lyz5Ger/47u3yj9H2xLf8lyAj8=                 41
# 6   +0MeUJe1cGb4O97gJoTPUPjiONQzi9BmxDuKRZn+E2o=                 41
# 7   +0W3Q9FSw8TLgoNke9JFl6dUeoxAOfuHarEexRPcJsA=                 41
# 8   +0aofSeKQ/F2bhtAGW/zrdrw+lGVV6nmIdt8hJRTR/8=                 41
# 9   +0c0aay0C6GHocNyfqE+46Ih4dYOy2P5xjc0GjGgBTE=                 41
# 10  +0vdYjwKTJKP2OuVUWMqqjFKwp83QG4URcLg1vvFxek=                 41
# 11  +1qe9o7V7yJ6CWz4nO2r/Y3a6lTIRf53Q7eSQyQBUJQ=                 40
# 12  +1sa2M+60tj9HplZSnzW8BCiYEskEMTfwKrOhHjGb3I=                 16
# ...

# %%
df_0[1:2] 
df_0['msno']
# Out:
#                                            msno  payment_method_id  \
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 1                 30              149                 149              1
#
#    transaction_date  membership_expire_date  is_cancel
# 1          20150809                20190412          0

# %%
df_0.ix[0]##### = 첫번째 row (=index) 가져오기
# Out:
# msno                      ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=
# payment_method_id                                                   32
# payment_plan_days                                                   90
# plan_list_price                                                    298
# actual_amount_paid                                                 298
# is_auto_renew                                                        0
# transaction_date                                              20170131
# membership_expire_date                                        20170504
# is_cancel                                                            0
# Name: 0, dtype: object

# %%
len(df_0)
## 반복문 쓸때 그냥 for i in range(len(data)) 하면 실재 row 의 수만큼 돌아간다.
# Out:
# 1431009

# %%
len_1 = []
for i in range(len(df_0)):
    len_1.append(i) 
len(len_1)
### len = 0 부터 시작 = range 는 0 부터 시작
# Out:
# 1431009

# %%
### 로우 삭제
# data.drop(["로우 이름"])
### col 삭제
# data.drop("col이름")

# %%
### row 인덱스 쓸때 : ix 말고 loc 써라

# %%
### list_price 가 0 인거 없애기
for i in range(len(df_0)):
    if df_0.loc[i]["plan_list_price"] == 0:
        print(df_0.loc[i])
        df_0 = df_0.drop([i])
    else:
        if df_0.loc[i]["plan_list_price"] != df_0.loc[i]["actual_amount_paid"]:
            print(df_0.loc[i])
            df_0 = df_0.drop([i])
        else:
            if df_0.loc[i]["payment_plan_days"] == 0:
                print(df_0.loc[i])
                df_0 = df_0.drop([i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [93] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e56915460700> in <module>()
#       1 ### list_price 가 0 인거 없애기
#       2 for i in range(len(df_0)):
# ...

# %%
df_0.ix[2]["actual_amount_paid"]
# Out:
# 180

# %%
df_0.loc[93]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [93] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-1e047fda9bbd> in <module>()
# ----> 1 df_0.loc[93]
#
# ...

# %%
df_0.ix[2]
# Out:
# msno                      +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=
# payment_method_id                                                   36
# payment_plan_days                                                   30
# plan_list_price                                                    180
# actual_amount_paid                                                 180
# is_auto_renew                                                        1
# transaction_date                                              20170303
# membership_expire_date                                        20170422
# is_cancel                                                            0
# Name: 2, dtype: object
